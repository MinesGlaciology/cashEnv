# %%
# %matplotlib notebook

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import rasterio as rio
import os

# %%
# replace path name to your directory that has all_tiles_april
tile_dir = "/home/data/all_tiles_april/"
file_list = os.listdir(tile_dir)
file_list.sort()

# %%
tile = np.random.choice(file_list)
sample = rio.open(tile_dir + tile)
coords = sample.lnglat()

# %%
plt.imshow(sample.read().reshape((200,200)))
plt.colorbar()
print(tile)
print(coords)
# Out:
# <img src="data:image/png;base64,..." width="640">
# c97bc1040ea8b05eaffbca8a48d8ca81199414dc54922f0099bb90a5be8ea48a.tif
# (-48.96991436124489, 66.57529568222444)

# %%
#test = rio.open("/home/data/all_tiles_april/c97bc1040ea8b05eaffbca8a48d8ca81199414dc54922f0099bb90a5be8ea48a.tif")
#plt.imshow(test.read().reshape((200,200)))
#plt.colorbar()
